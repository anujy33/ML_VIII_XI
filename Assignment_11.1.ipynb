# %% [markdown]
# Question:- In this assignment students have to find the frequency of words in a webpage. User can
# use urllib and BeautifulSoup to extract text from webpage.

# %%
from bs4 import BeautifulSoup
import urllib.request
import nltk

response = urllib.request.urlopen('http://php.net/')
html = response.read()
soup = BeautifulSoup(html,"html5lib")

from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.corpus import stopwords
text = soup.get_text()
words = word_tokenize(text)
words_imp = [w for w in words if w not in nltk.corpus.stopwords.words('english')]
frequency = nltk.FreqDist(words_imp)
# %matplotlib inline
frequency.plot(50)

# %%
frequency.most_common(50)
# Out:
# [('.', 93),
#  ('PHP', 81),
#  (',', 37),
#  ('The', 28),
#  ('release', 23),
#  ('source', 20),
#  ('downloads', 20),
#  ('found', 20),
#  ('For', 19),
#  ('7.2.0', 19),
#  ('list', 18),
#  ('Extensions', 16),
#  ('page', 16),
#  ('version', 16),
#  ('Release', 14),
#  ('Candidate', 14),
#  ('file', 13),
#  ('Windows', 13),
#  ('This', 13),
#  ('development', 13),
#  ('Released', 13),
#  ('team', 13),
#  ('please', 13),
#  ('visit', 13),
#  ('changes', 13),
#  ('also', 12),
#  ('announces', 12),
#  ('immediate', 12),
#  ('availability', 12),
#  ('users', 12),
#  ('encouraged', 12),
#  ('binaries', 12),
#  ('2018', 11),
#  ('read', 11),
#  ('All', 11),
#  ('bug', 8),
#  ('3', 8),
#  ('files', 7),
#  ('Alpha', 7),
#  ('test', 7),
#  ('upgrade', 7),
#  ('windows.php.net/download/', 7),
#  ('recorded', 7),
#  ('ChangeLog', 7),
#  ('bugs', 7),
#  ('-', 7),
#  ('A', 6),
#  ('g', 6),
#  ('1', 6),
#  ('download', 6)]

# %%
frequency.plot(50)
